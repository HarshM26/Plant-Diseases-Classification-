# %%
# Install and import necessary libraries
import numpy as np
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt
import time
# %matplotlib inline
import cv2
import os
from tensorflow import keras
import glob as gb
import pandas as pd
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.layers.experimental.preprocessing import RandomFlip, RandomRotation
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPool2D, LeakyReLU
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.models import Sequential

# %%
# !pip install split-folders
# Out:
# Collecting split-folders
#   Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1

# %%
import splitfolders

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
direactory_org = "/content/drive/MyDrive/Tomato_leaf_diseases"
splitfolders.ratio(direactory_org,
            output="splitted_data",
            seed=42,
            ratio=(.8, .1,.1),
            group_prefix=None,
            move=False)
# Out:
# Copying files: 1806 files [01:36, 18.69 files/s]

# %%
# Set image size and batch size
IMG_SIZE = (224, 224)
BATCH_SIZE = 128

# %%
# Load the dataset and split it into training (80%), validation (10%), and test (10%) sets
directory = "/content/splitted_data"
train_dataset = image_dataset_from_directory(directory+'/train',
                                       shuffle=True,
                                       labels='inferred',
                                       batch_size=BATCH_SIZE,
                                       image_size=IMG_SIZE,
                                       color_mode='rgb',
                                       seed=42)

# Splitting the validation and test sets (each 10% of the dataset)
val_dataset = image_dataset_from_directory(directory+'/val',
                                           shuffle=True,
                                           labels='inferred',
                                           batch_size=BATCH_SIZE,
                                           image_size=IMG_SIZE,
                                           color_mode='rgb',
                                           seed=42)

test_dataset = image_dataset_from_directory(directory+'/test',
                                            shuffle=True,
                                            labels='inferred',
                                            batch_size=BATCH_SIZE,
                                            image_size=IMG_SIZE,
                                            color_mode='rgb',
                                            seed=43)
# Out:
# Found 1442 files belonging to 6 classes.
# Found 178 files belonging to 6 classes.
# Found 186 files belonging to 6 classes.

# %%
class_names = train_dataset.class_names
class_names
# Out:
# ['_tomato_bacterial_wilt',
#  '_tomato_blight_leaf',
#  '_tomato_brown_spots',
#  '_tomato_healthy',
#  '_tomato_leaf_mosaic_virus',
#  '_tomato_leaf_yellow_virus']

# %%
output_class = len(class_names)

# %%
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip("horizontal"),
  tf.keras.layers.RandomRotation(0.2),
  tf.keras.layers.RandomZoom(0.2),
  tf.keras.layers.RandomHeight(0.2),
  tf.keras.layers.RandomWidth(0.2),
])

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)

# %%
IMG_SHAPE = IMG_SIZE +(3,)
# base_model = tf.keras.applications.InceptionV3(input_shape=IMG_SHAPE, include_top= False,weights='imagenet')
#base_model = tf.keras.applications.VGG16(include_top=False, weights="imagenet", input_shape=IMG_SHAPE)
# For DenseNet121
base_model = tf.keras.applications.DenseNet121(
    include_top=False,
    weights="imagenet",
    input_shape=IMG_SHAPE,
    pooling='max'
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 3s 0us/step

# %%
type(base_model)
# preprocess_input = tf.keras.applications.inception_v3.preprocess_input
preprocess_input = tf.keras.applications.densenet.preprocess_input

# %%
nb_layers = len(base_model.layers)
print("Numbers of Layers =" , nb_layers)
print(base_model.layers[nb_layers - 2].name)  # pre- Last name
print(base_model.layers[nb_layers - 1].name)
# Out:
# Numbers of Layers = 428
# relu
# max_pool

# %%
def plant_leaf_model( image_shape=IMG_SIZE):

    image_shape = image_shape + (3,)

    DenseNet121_model = tf.keras.applications.DenseNet121(include_top=False, weights="imagenet", input_shape=IMG_SHAPE)
    DenseNet121_model.trainable = True
    for layer in DenseNet121_model.layers[0 : 291]:
        layer.trainable = False

    inputs = tf.keras.Input(image_shape)
    x = data_augmentation(inputs)
    x = preprocess_input(inputs)
    x = DenseNet121_model(x , training=False)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dropout(0.2)(x)
    prediction_layer = tf.keras.layers.Dense(6 ,activation = "softmax")
    outputs = prediction_layer(x)
    model = tf.keras.Model(inputs, outputs)
    model.summary()
    return model

# %%
# Print model summary
Plant_Leaf_Model = plant_leaf_model(IMG_SIZE)
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.math.truediv (TFOpLambd  (None, 224, 224, 3)       0
#  a)
#
#  tf.nn.bias_add (TFOpLambda  (None, 224, 224, 3)       0
#  )
#
#  tf.math.truediv_1 (TFOpLam  (None, 224, 224, 3)       0
#  bda)
#
#  densenet121 (Functional)    (None, 7, 7, 1024)        7037504
#
#  global_average_pooling2d (  (None, 1024)              0
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense (Dense)               (None, 6)                 6150
#
# =================================================================
# Total params: 7043654 (26.87 MB)
# Trainable params: 3057734 (11.66 MB)
# Non-trainable params: 3985920 (15.21 MB)
# _________________________________________________________________

# %%
base_learning_rate = 0.001
Plant_Leaf_Model.compile(optimizer=tf.keras.optimizers.Nadam(learning_rate=base_learning_rate),
                           loss=tf.keras.losses.SparseCategoricalCrossentropy(),
                           metrics=['accuracy'])

# %%
start_time = time.time()
history = Plant_Leaf_Model.fit(train_dataset , verbose=1 , epochs=30 , validation_data=val_dataset , use_multiprocessing= True)
end_time = time.time()
# Out:
# Epoch 1/30
# 12/12 [==============================] - 132s 2s/step - loss: 1.8232 - accuracy: 0.4390 - val_loss: 1.1966 - val_accuracy: 0.6292
# Epoch 2/30
# 12/12 [==============================] - 69s 2s/step - loss: 0.9239 - accuracy: 0.6845 - val_loss: 0.7683 - val_accuracy: 0.7528
# Epoch 3/30
# 12/12 [==============================] - 65s 2s/step - loss: 0.6123 - accuracy: 0.7767 - val_loss: 0.5285 - val_accuracy: 0.7472
# Epoch 4/30
# 12/12 [==============================] - 68s 2s/step - loss: 0.4913 - accuracy: 0.8079 - val_loss: 0.4703 - val_accuracy: 0.7921
# Epoch 5/30
# 12/12 [==============================] - 66s 2s/step - loss: 0.4614 - accuracy: 0.8024 - val_loss: 0.4287 - val_accuracy: 0.8146
# Epoch 6/30
# 12/12 [==============================] - 70s 2s/step - loss: 0.3909 - accuracy: 0.8377 - val_loss: 0.4899 - val_accuracy: 0.8090
# Epoch 7/30
# 12/12 [==============================] - 71s 2s/step - loss: 0.4425 - accuracy: 0.8051 - val_loss: 0.4292 - val_accuracy: 0.8258
# Epoch 8/30
# 12/12 [==============================] - 65s 2s/step - loss: 0.3551 - accuracy: 0.8530 - val_loss: 0.3302 - val_accuracy: 0.8820
# Epoch 9/30
# 12/12 [==============================] - 67s 2s/step - loss: 0.3214 - accuracy: 0.8613 - val_loss: 0.5167 - val_accuracy: 0.7865
# Epoch 10/30
# 12/12 [==============================] - 72s 2s/step - loss: 0.3531 - accuracy: 0.8558 - val_loss: 0.4573 - val_accuracy: 0.7865
# Epoch 11/30
# 12/12 [==============================] - 70s 2s/step - loss: 0.2833 - accuracy: 0.8759 - val_loss: 0.3347 - val_accuracy: 0.8820
# Epoch 12/30
# 12/12 [==============================] - 60s 2s/step - loss: 0.2593 - accuracy: 0.8814 - val_loss: 0.5026 - val_accuracy: 0.8258
# Epoch 13/30
# 12/12 [==============================] - 65s 2s/step - loss: 0.2869 - accuracy: 0.8752 - val_loss: 0.4152 - val_accuracy: 0.8764
# Epoch 14/30
# 12/12 [==============================] - 68s 2s/step - loss: 0.2300 - accuracy: 0.8890 - val_loss: 0.3352 - val_accuracy: 0.8876
# Epoch 15/30
# 12/12 [==============================] - 64s 2s/step - loss: 0.2179 - accuracy: 0.9008 - val_loss: 0.4192 - val_accuracy: 0.8483
# Epoch 16/30
# 12/12 [==============================] - 68s 2s/step - loss: 0.4829 - accuracy: 0.8169 - val_loss: 0.6740 - val_accuracy: 0.7865
# Epoch 17/30
# 12/12 [==============================] - 60s 2s/step - loss: 0.3882 - accuracy: 0.8481 - val_loss: 0.6793 - val_accuracy: 0.8090
# Epoch 18/30
# 12/12 [==============================] - 69s 2s/step - loss: 0.3908 - accuracy: 0.8551 - val_loss: 0.4747 - val_accuracy: 0.7753
# Epoch 19/30
# 12/12 [==============================] - 71s 2s/step - loss: 0.2781 - accuracy: 0.8696 - val_loss: 0.4377 - val_accuracy: 0.8764
# Epoch 20/30
# 12/12 [==============================] - 63s 2s/step - loss: 0.2321 - accuracy: 0.8953 - val_loss: 0.4113 - val_accuracy: 0.8427
# Epoch 21/30
# 12/12 [==============================] - 69s 2s/step - loss: 0.2017 - accuracy: 0.9057 - val_loss: 0.3881 - val_accuracy: 0.8202
# Epoch 22/30
# 12/12 [==============================] - 65s 2s/step - loss: 0.1821 - accuracy: 0.9036 - val_loss: 0.9050 - val_accuracy: 0.7528
# Epoch 23/30
# 12/12 [==============================] - 65s 2s/step - loss: 0.3573 - accuracy: 0.8710 - val_loss: 0.4877 - val_accuracy: 0.8596
# Epoch 24/30
# 12/12 [==============================] - 68s 2s/step - loss: 0.2043 - accuracy: 0.9022 - val_loss: 0.5158 - val_accuracy: 0.8539
# Epoch 25/30
# 12/12 [==============================] - 65s 2s/step - loss: 0.1881 - accuracy: 0.9098 - val_loss: 0.3721 - val_accuracy: 0.8539
# Epoch 26/30
# 12/12 [==============================] - 69s 2s/step - loss: 0.4271 - accuracy: 0.8564 - val_loss: 0.5340 - val_accuracy: 0.7079
# Epoch 27/30
# 12/12 [==============================] - 73s 2s/step - loss: 0.3268 - accuracy: 0.8606 - val_loss: 0.4446 - val_accuracy: 0.8371
# Epoch 28/30
# 12/12 [==============================] - 63s 2s/step - loss: 0.2389 - accuracy: 0.8932 - val_loss: 0.5791 - val_accuracy: 0.7865
# Epoch 29/30
# 12/12 [==============================] - 69s 2s/step - loss: 0.1992 - accuracy: 0.9015 - val_loss: 0.5681 - val_accuracy: 0.7640
# Epoch 30/30
# 12/12 [==============================] - 70s 2s/step - loss: 0.1928 - accuracy: 0.9085 - val_loss: 0.4115 - val_accuracy: 0.8146

# %%
# Time taken to train the model
time_taken_seconds  = (end_time - start_time)
# Convert to hours, minutes, and seconds
hours = int(time_taken_seconds // 3600)
minutes = int((time_taken_seconds % 3600) // 60)
seconds = int(time_taken_seconds % 60)

print(f"Time taken to train the model: {hours} hours, {minutes} minutes, {seconds} seconds")
# Out:
# Time taken to train the model: 0 hours, 36 minutes, 28 seconds

# %%
# Evaluate the model on the test set
test_loss, test_accuracy = Plant_Leaf_Model.evaluate(test_dataset)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# 2/2 [==============================] - 12s 6s/step - loss: 0.4840 - accuracy: 0.7957
# Test Loss: 0.4840
# Test Accuracy: 0.7957

# %%
Plant_Leaf_Model.evaluate(val_dataset , verbose = 1)
# Out:
# 2/2 [==============================] - 8s 144ms/step - loss: 0.4115 - accuracy: 0.8146
# [0.4114786982536316, 0.8146067261695862]

# %%
import os

model_name = 'DenseNet'
save_dir = '/content/drive/MyDrive/weightsave/densenet/'

# Create the directory if it doesn't exist
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

# Save the model weights in H5 format with the model name
base_model.save_weights(f'{save_dir}{model_name}_weights.h5')

# Save the entire model in H5 format with the model name
base_model.save(f'{save_dir}{model_name}.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
plt.figure(figsize=(20, 15))
for images, labels in train_dataset.take(1):
    for i in range(25):
        plt.subplot(5,5,i+1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.axis("off")
        im2 = images[i].numpy().astype("uint8")
        img2 = tf.expand_dims(im2, 0)
        predict = Plant_Leaf_Model.predict(img2)
        predicted= class_names[np.argmax(predict)]
        actual = class_names [labels[i].numpy().astype("uint8")]
        if (actual == predicted):
            plt.title(predicted, fontsize=10, color= 'blue', pad=15);
        else :
            plt.title(actual, fontsize=10, color= 'red' ,pad=15);
        plt.subplots_adjust(left=0.1,bottom=0.1, right=0.9,
                            top=0.9, wspace=0.4,hspace=0.4)
# Out:
# 1/1 [==============================] - 7s 7s/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 50ms/step

# %%
acc = [0.] + history.history['accuracy']
val_acc = [0.] + history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(17, 12))
plt.subplot(2, 2, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([min(plt.ylim()),1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,3.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
# Number of input nodes
num_input_nodes = np.prod(IMG_SIZE) * 3  # IMG_SIZE (height, width) * 3 (RGB channels)
print(f'Number of input nodes: {num_input_nodes}')
# Out:
# Number of input nodes: 150528

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
# Plot training & validation loss values
plt.subplot(2, 1, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()
